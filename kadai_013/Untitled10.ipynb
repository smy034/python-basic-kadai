# %%
def add_two_arguments(price, shipping_fee):
    # 与えられた引数priceと引数shipping_feeを乗算し、変数totalに代入する
    total = int (price * shipping_fee)

    # 変数$totalの値を出力する
    print(f"{total}円")

# 関数を呼び出し、引数として購入金額と送料を渡す
add_two_arguments(100, 1.1)
# Out:
# 110円
